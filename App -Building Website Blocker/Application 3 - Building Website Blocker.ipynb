# %% [markdown]
# Setting up the Script

# %%
import time

hosts_path=r"hosts"
redirect='127.0.0.1'
website_list=['https://www.kongregate.com','http://www.addictinggames.com','addictinggames.com']

while True:
    print(1)
    time.sleep(5)
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-511531ffd839> in <module>()
#       7 while True:
#       8     print(1)
# ----> 9     time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# Setting up/Implementing the Infinite Loop

# %%
import time
from datetime import datetime as dt

hosts_path=r"hosts"
redirect='127.0.0.1'
website_list=['https://www.kongregate.com','kongregate.com','http://www.addictinggames.com','addictinggames.com']

while True:
    if dt(dt.now().year,dt.now().month,dt.now().day,8)< dt.now()<dt(dt.now().year,dt.now().month,dt.now().day,16):
        print('Working Hours...')
    else:
        print('Fun Hours...')
    time.sleep(5)

# %% [markdown]
# Implementing the First Part

# %%
import time
from datetime import datetime as dt


hosts_path=r"C:\Windows\System32\drivers\etc\hosts"
hosts_temp="hosts"
redirect='127.0.0.1 '
website_list=['https://www.kongregate.com','kongregate.com','http://www.addictinggames.com','addictinggames.com']

while True:
    if dt(dt.now().year,dt.now().month,dt.now().day,8)< dt.now()<dt(dt.now().year,dt.now().month,dt.now().day,18):
        print('Working Hours...') 
        with open(hosts_temp,'r+') as file:
            content=file.read()
            print('Content is here: "', content)
            for i in website_list:
                if i in content:
                    pass
                else:
                    file.write(redirect + " " + i+"\n")
                    print(file)
    else:
        print('Fun Hours...')
    time.sleep(5)
# Out:
# Working Hours...
# Content is here: " # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost# Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# ...

# %% [markdown]
# Implementing the Second Part

# %%
import time
from datetime import datetime as dt

hosts_path=r"../hosts2"
hosts_temp="hosts"
redirect='127.0.0.1 '
website_list=['https://www.kongregate.com','kongregate.com','http://www.addictinggames.com','addictinggames.com']

while True:
    if dt(dt.now().year,dt.now().month,dt.now().day,8)< dt.now()<dt(dt.now().year,dt.now().month,dt.now().day,16):
        print('Working Hours...') 
        with open(hosts_path,'r+') as file:
            content=file.read()
            for i in website_list:
                if i in co ntent:
                    pass
                else:
                    file.write(redirect + " " + i)
    else: 
        with open(hosts_path, 'r+') as file:
            content=file.readlines()
            file.seek(0) #moves to start of text so it starts at first, 0 , line
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
            file.truncate() #stops file from repeating
        print('Fun Hours...')
    time.sleep(5)
# Out:
# Working Hours...
# Working Hours...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-566f87daf334> in <module>()
#      26             file.truncate() #stops file from repeating
#      27         print('Fun Hours...')
# ---> 28     time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# Scheduling the Python Program on Mac/Linux

# %% [markdown]
# ### Final Code/Code Example

# %%
import time
from datetime import datetime as dt

hosts_path=r"../hosts"
redirect='127.0.0.1'
website_list=['https://www.kongregate.com','kongregate.com','http://www.addictinggames.com','addictinggames.com'] 
final_list=[redirect + " " + i for i in website_list]
final_string_block ="\n".join(final_list)

while True:
    if dt(dt.now().year,dt.now().month,dt.now().day,8) < dt.now()<dt(dt.now().year,dt.now().month,dt.now().day,18):
        print ('Work Time...')
        with open(hosts_path,'r+') as file:
            content=file.read()
            print (content)
            for website in website_list:
                if website in content:
                    pass
                else:
                    file.write(redirect+" "+website+"\n")
    else:
        with open(hosts_path, 'r+') as file:
            content=file.readlines()
            file.seek(0)
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
            file.truncate()
        print('Fun Time')
        time.sleep(5)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
